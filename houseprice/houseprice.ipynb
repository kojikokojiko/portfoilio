# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# # いつものルーティーン

# %%
df_train=pd.read_csv('./input/train.csv')
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test=pd.read_csv('./input/test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# データの詳細を確認

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df_train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # データの最頻値を確認

# %%
df_train.SalePrice.mode()
# Out:
# 0    140000
# dtype: int64

# %% [markdown]
# # SalePriceをヒストグラムで分析
#
# * 横軸にSalePrice
# * 縦軸に割合

# %%
sns.distplot(df_train.SalePrice);

# %% [markdown]
# # グラフとデータからわかる特徴
#
# * 最頻値は150000ぐらいの値割合が一番多い
# * 極端に高い金額のものが存在する
# * 正規分布ではない（求めたい値が正規分布をしているほど精度がよくなるらしい）

# %% [markdown]
# # 相関係数を出してやる

# %%
corrmat=df_train.corr()
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# 算出した相関係数を相間が高い順に上位10個のデータを表示

# %%
k=10

cols=corrmat.nlargest(k,'SalePrice')['SalePrice'].index
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
cm=df_train.loc[:,cols]
cm
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0        208500            7       1710           2         548          856
# 1        181500            6       1262           2         460         1262
# 2        223500            7       1786           2         608          920
# 3        140000            7       1717           3         642          756
# 4        250000            8       2198           3         836         1145
# ...         ...          ...        ...         ...         ...          ...
# 1455     175000            6       1647           2         460          953
# 1456     210000            6       2073           2         500         1542
# 1457     266500            7       2340           1         252         1152
# 1458     142125            5       1078           1         240         1078
# 1459     147500            5       1256           1         276         1256
#
# ...

# %%
cm_corr=cm.corr()
cm_corr
# Out:
#               SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  \
# SalePrice      1.000000     0.790982   0.708624    0.640409    0.623431
# OverallQual    0.790982     1.000000   0.593007    0.600671    0.562022
# GrLivArea      0.708624     0.593007   1.000000    0.467247    0.468997
# GarageCars     0.640409     0.600671   0.467247    1.000000    0.882475
# GarageArea     0.623431     0.562022   0.468997    0.882475    1.000000
# TotalBsmtSF    0.613581     0.537808   0.454868    0.434585    0.486665
# 1stFlrSF       0.605852     0.476224   0.566024    0.439317    0.489782
# FullBath       0.560664     0.550600   0.630012    0.469672    0.405656
# TotRmsAbvGrd   0.533723     0.427452   0.825489    0.362289    0.337822
# YearBuilt      0.522897     0.572323   0.199010    0.537850    0.478954
#
#               TotalBsmtSF  1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt
# SalePrice        0.613581  0.605852  0.560664      0.533723   0.522897
# ...

# %% [markdown]
# SalePriceとの相関係数上位10個をヒートマップで表示

# %%
sns.set(font_scale=1.25)

hm=sns.heatmap(cm_corr,cbar=True,annot=True,square=True,annot_kws={'size':10},fmt='.2f',yticklabels=cols.values,xticklabels=cols.values)

# %% [markdown]
# 少し見切れてしまっているのは申し訳ないです

# %% [markdown]
# SalePriceと相関の強いOverQualとGrLivAreaの散布図の表示

# %%
sns.set()
cols=['SalePrice','OverallQual','GrLivArea']
sns.pairplot(df_train[cols],height=3)
plt.show()

# %% [markdown]
# SalePriceとGrLivAreaの相間関係が強そう
# →
# 線形回帰したい
# →
# だけど外れ値が気持ち悪い
# →
# SalePriceとGrLivAreaの相間から外れた値（GrLivAreaの上位二つ）があるのでその二つを排除していく

# %%
df_train.sort_values(by="GrLivArea",ascending=False)
# sort_valueで降順に並び替えをする
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 528    529          30       RL         58.0     9098   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 1100  1101          30       RL         60.0     8400   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
#
# ...

# %%
df_train=df_train.drop(index=df_train[df_train['Id']==1299].index)

df_train=df_train.drop(index=df_train[df_train['Id']==524].index)
#　Idが1299と524を持つデータのindexを取り出して除去

# %%
#ちゃんと消えているか確認
df_train.sort_values(by="GrLivArea",ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 528    529          30       RL         58.0     9098   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 1100  1101          30       RL         60.0     8400   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
#
# ...

# %%
sns.set()
cols=['SalePrice','OverallQual','GrLivArea']
sns.pairplot(df_train[cols],height=3)
plt.show()

# %% [markdown]
# SalesPriceとGrLivAreaの相関図から線形回帰を行う

# %%
X=df_train[['GrLivArea']].values
y=df_train['SalePrice'].values

slr=LinearRegression()
slr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(X,y)
plt.plot(X,slr.predict(X),color='red')
plt.show()

# %%
X_test=df_test[['GrLivArea']].values

# %%
y_test_pred=slr.predict(X_test,)
y_test_pred
# Out:
# array([110244.79464727, 160057.10728358, 194569.10218171, ...,
#        147977.90906923, 118757.75338881, 237248.9358724 ])

# %%
df_test['SalePrice']=y_test_pred

# %%
df_test[['Id','SalePrice']].head()
# Out:
#      Id      SalePrice
# 0  1461  110244.794647
# 1  1462  160057.107284
# 2  1463  194569.102182
# 3  1464  191693.102607
# 4  1465  154420.148117

# %%
df_test[['Id','SalePrice']].to_csv('submission.csv' ,index=False)

# %%
pd.read_csv('submission.csv')
# Out:
#         Id      SalePrice
# 0     1461  110244.794647
# 1     1462  160057.107284
# 2     1463  194569.102182
# 3     1464  191693.102607
# 4     1465  154420.148117
# ...    ...            ...
# 1454  2915  132792.631314
# 1455  2916  132792.631314
# 1456  2917  147977.909069
# 1457  2918  118757.753389
# 1458  2919  237248.935872
#
# [1459 rows x 2 columns]

# %% [markdown]
# 精度はRMSEで評価して0.28783でした。
